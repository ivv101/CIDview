# %%
current_version = '5b6'

# %%
import os
import pandas as pd
import numpy as np

import datetime

# import re

import json

# from airium import Airium

from distinctipy import distinctipy

from pydoc import importfile

import sys
import copy

code_dir = sys.path[0]

# print(sys.path[0])

# %%
with open(f'{code_dir}/bokeh_modules.py', 'wt') as _:
    _.write(
'''
from bokeh.embed import file_html, json_item, autoload_static, components
from bokeh.events import Tap
from bokeh.io import curdoc, output_notebook
from bokeh.layouts import layout, column, row
from bokeh.models import ColumnDataSource, CustomJS, Slider, Legend, \
        Button, CheckboxButtonGroup, RadioButtonGroup, RadioGroup, CheckboxGroup, Label, Spacer, Title, Div, \
        PanTool, WheelZoomTool, SaveTool, ResetTool, HoverTool, TapTool, \
        BasicTicker, Scatter, CustomJSHover, FileInput, Toggle, TableColumn, DataTable, TextAreaInput, \
        TabPanel, Tabs, DateFormatter, LogColorMapper, LinearColorMapper, ColorBar, TextInput, PreText
from bokeh.plotting import figure, output_file, show, save
from bokeh.resources import CDN
from bokeh.themes import Theme
from bokeh.util.compiler import TypeScript
''')
import bokeh_modules as bk 
import importlib
importlib.reload(bk)
import bokeh.palettes as bkp

os.system(f'rm {code_dir}/bokeh_modules.py')
# Out:
# 0

# %%
arrmap = lambda f, x : [f(_) for _ in x]

# %%
def is_interactive():
    # print('sys.argv[0]:', sys.argv[0])
    # import __main__ as main
    # return not hasattr(main, '__file__')

    return True if sys.argv[0].split('/')[-1]=='ipykernel_launcher.py' else False

print(f'interactive: {is_interactive()}')
# Out:
# interactive: True

# %%
if is_interactive():
    bk.output_notebook(hide_banner=True)

# %%
settings_dir = f'{code_dir}/../settings/'
data_dir = f'{code_dir}/../data/'
html_dir = f'{code_dir}/../html/'

# %%
if is_interactive():
    inputes = {
        
        # 'CXO_published': ['CSC_TD_v5_MW_remove.csv', 'CXO_settings_published.json'],  
        'CXO_published': ['CSC_TD_v5_MW_remove.csv', 'CXO_settings_published.json'],   
        'XMM': ['XMM_DR11_TDSET.csv', 'XMM_settings.json'],
        'XDBS': ['XDBS_catalog.csv', ''],

        # 'CXO_updated': ['CSC_TD_v5_0910_MW_remove.csv', 'CXO_settings_updated.json'],
        'CXO_test': ['CSC_TD_v5_01052022_MW_remove_8class.csv', 'CXO_settings_8class.json'],  
        # 'CXO_test': ['CSC_TD_v5_Topcat_removecode.csv', 'CSC_TD_v5_Topcat_removecode_settings.json'],
        'XMM_test': ['XMM_DR11_TDSET.csv', 'XMM_DR11_TDSET_settings.json'],    
        'XDBS_test': ['XDBS_catalog.csv', 'XDBS_catalog_settings_test.json'],
        'XDBS_hui': ['XDBS_catalog.csv', 'XDBS_catalog_settings_hui.json'],   
        
        'GClass': ['gll_pcs_v28.csv', 'gll_pcs_v28_settings.json']
    }

    catalog = 'GClass'
    
    input_file_name, q_file_name = inputes[catalog]
    
    input_file_name = data_dir + input_file_name
    q_file_name = settings_dir + q_file_name
    
else: 
    
    input_file_name = sys.argv[1]
        
    q_file_name = sys.argv[2] if len(sys.argv[1:])>1 else ''       
        
    catalog = 'GClass' if input_file_name=='gll_pcs_v28.csv' else ''

# %%
print(f'{code_dir}/{current_version}.py')
# Out:
# /Users/oyk100/CIDview/code/5b6.py

# %%
mdl = importfile(f'{code_dir}/{current_version}.py')

# %%
set_mdl = importfile(f'{code_dir}/settings_tab.py')

# %%
df_raw = pd.read_csv(input_file_name)

# if input_file_name == 'CSC_TD_v5_MW_remove.csv':
#     df_raw = df_raw[df_raw.remove_code==0]

if 'remove_code' in df_raw.columns:
    df_raw = df_raw[df_raw.remove_code==0]
    
df, q_original = mdl.get_df_q_derived_func(df_raw, q_file_name)
# Out:
# ['Name', 'RAJ2000', 'DEJ2000', 'Gal_l', 'Gal_b', 'Size', 'Signif', 'Pivot_E', 'Flux', 'F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'PL_Index', 'LP_Index', 'LP_SigCurv', 'Var_Indx', 'ASSOC1', 'Class', 'HR1', 'HR2', 'HR3']

# %%
order = ['hide_upload_button', 'hide_csv_etc_button', 'include_version', 'hide_settings_panel', 
         # 'show_TEV (GClass)',
         'all', 'derived', 
         'class_column', 'hover_table_names', 
         'non_features', 'log_features', 'features_no_loglin', 'flipped_axis', 
         'ini_xy_text', 
         'table_row1_labels_active', 'table_row2_labels_active',
         'webpage_name', 'title_text', 'cite_text', 
         'ackn_text', 'description_text', 'contact_text', 'html_title', 'help_text', 
         'get_ref_link_js', 'format_js', 'derived_func_js', 'derived_func_py']

# %%
q_label_name = 'label'

q = copy.deepcopy(q_original)

q_mod = {k: [v] for k, v in q.items()}

q_original_source = bk.ColumnDataSource(data=q_mod)
q_modified_source = bk.ColumnDataSource(data=q_mod)

w = {}

for feat in ['hide_upload_button', 'hide_csv_etc_button', 'include_version', 'hide_settings_panel']:        
    w[feat] = set_mdl.w_checkbox(feat, q, q_modified_source)

# %%
df_source = bk.ColumnDataSource(data=df, name='df_source')

w['class_column'], df_source = set_mdl.w_class(q, q_modified_source, df, q_original_source)

w['hover_table_names'] = set_mdl.w_hover_table_names(q, q_modified_source)

w['non_features'] = set_mdl.w_misc('non_features', q, q_modified_source)
# w['features'] = set_mdl.w_misc('features', q, q_modified_source) # assume that always rest
w['log_features'] = set_mdl.w_misc('log_features', q, q_modified_source)
w['features_no_loglin'] = set_mdl.w_misc('features_no_loglin', q, q_modified_source)
w['flipped_axis'] = set_mdl.w_misc('flipped_axis', q, q_modified_source)

w['ini_xy_text'] = set_mdl.w_ini_xy_text(q, q_modified_source)

w['table_row1_labels_active'] = set_mdl.w_misc('table_row1_labels_active', q, q_modified_source)
w['table_row2_labels_active'] = set_mdl.w_misc('table_row2_labels_active', q, q_modified_source)

for feat in ['webpage_name', 'title_text', 'cite_text', 'ackn_text', 'description_text', 
             'contact_text', 'html_title']:

    w[feat] = set_mdl.w_text_input(feat, q, q_modified_source)

for feat in ['help_text', 'get_ref_link_js', 'format_js', 'derived_func_js', 'derived_func_py']:

    w[feat] = set_mdl.w_text_area_input(feat, q, q_modified_source)

w['derived'] = set_mdl.w_derived(q, q_modified_source)

w_misc_rows = {}
radio_rows = {}
for s in order:    
    if s in w:   
        
        sel = list(w[s].select(dict(tags='w_misc')))
        
        if sel!=[]:             
            w_misc_rows[s] = sel[0]
            
        sel = list(w[s].select(dict(tags='radio')))
        
        if sel!=[]:             
            radio_rows[s] = sel 
                    
w_misc_rows = list(w_misc_rows.values())
radio_rows = list(radio_rows.values())  

# w_misc_rows = sum(w_misc_rows, [])
radio_rows = sum(radio_rows, [])

# %%
w['all'], json_q = set_mdl.w_all(q, q_modified_source, q_original_source, w_misc_rows, radio_rows, df_source, json_visible=False)

button_save = set_mdl.button_save_func(q_modified_source, q_original_source, input_file_name, json_q)
w['hide_csv_etc_button'] = bk.row(w['hide_csv_etc_button'], bk.Spacer(width=300), button_save)

# %%
# layout_order = [button_save] + list(w.values())
layout_order = [w[i] for i in order]

settings_layout = bk.layout(layout_order)

# %%
# %%prun

legend_loc='above' 
legend_order='abc'
y_buttons_margin=0

if catalog=='GClass':
    legend_loc='right' 
    legend_order='size'
    y_buttons_margin=100


if 'special_plot' not in q_original:
    q_original['special_plot'] = {}
    
# for GClass
layout, p = mdl.main_func(df, q_original, 
                          legend_loc=legend_loc, 
                          legend_order=legend_order,
                          y_buttons_margin=y_buttons_margin)

# layout, df_list = mdl.main_func(df, q_original) # for everything else

bk.show(layout)
# Out:
# ---------------------------------------------------------------------------
# SerializationError                        Traceback (most recent call last)
# Cell In[18], line 24
#      17 layout, p = mdl.main_func(df, q_original,
#      18                           legend_loc=legend_loc,
#      19                           legend_order=legend_order,
#      20                           y_buttons_margin=y_buttons_margin)
#      22 # layout, df_list = mdl.main_func(df, q_original) # for everything else
# ---> 24 bk.show(layout)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/io/showing.py:143, in show(obj, browser, new, notebook_handle, notebook_url, **kwargs)
#     140 state = curstate()
#     142 if isinstance(obj, UIElement):
# --> 143     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     145 def is_application(obj: Any) -> TypeGuard[Application]:
#     146     return getattr(obj, '_is_a_bokeh_application_class', False)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/io/showing.py:190, in _show_with_state(obj, state, browser, new, notebook_handle)
#     188 if state.notebook:
#     189     assert state.notebook_type is not None
# --> 190     comms_handle = run_notebook_hook(state.notebook_type, 'doc', obj, state, notebook_handle)
#     191     shown = True
#     193 if state.file or not shown:
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/io/notebook.py:367, in run_notebook_hook(notebook_type, action, *args, **kwargs)
#     365 if _HOOKS[notebook_type][action] is None:
#     366     raise RuntimeError(f"notebook hook for {notebook_type!r} did not install {action!r} action")
# --> 367 return _HOOKS[notebook_type][action](*args, **kwargs)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/io/notebook.py:583, in show_doc(obj, state, notebook_handle)
#     581 from ..embed.notebook import notebook_content
#     582 comms_target = make_id() if notebook_handle else None
# --> 583 (script, div, cell_doc) = notebook_content(obj, comms_target)
#     585 publish_display_data({HTML_MIME_TYPE: div})
#     586 publish_display_data({JS_MIME_TYPE: script, EXEC_MIME_TYPE: ""}, metadata={EXEC_MIME_TYPE: {"id": obj.id}})
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/embed/notebook.py:90, in notebook_content(model, notebook_comms_target, theme)
#      87 # Comms handling relies on the fact that the new_doc returned here
#      88 # has models with the same IDs as they were started with
#      89 with OutputDocumentFor([model], apply_theme=theme, always_new=True) as new_doc:
# ---> 90     (docs_json, [render_item]) = standalone_docs_json_and_render_items([model])
#      92 div = div_for_render_item(render_item)
#      94 render_item = render_item.to_json()
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/embed/util.py:330, in standalone_docs_json_and_render_items(models, suppress_callback_warning)
#     328 docs_json: dict[ID, DocJson] = {}
#     329 for doc, (docid, _) in docs.items():
# --> 330     docs_json[docid] = doc.to_json(deferred=False)
#     332 render_items: list[RenderItem] = []
#     333 for _, (docid, roots) in docs.items():
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/document/document.py:728, in Document.to_json(self, deferred)
#     726 serializer = Serializer(deferred=deferred)
#     727 defs = serializer.encode(data_models)
# --> 728 roots = serializer.encode(self._roots)
#     730 doc_json = DocJson(
#     731     version=__version__,
#     732     title=self.title,
#     733     defs=defs,
#     734     roots=roots,
#     735 )
#     737 self.models.flush()
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:249, in Serializer.encode(self, obj)
#     247 self._circular[ident] = obj
#     248 try:
# --> 249     return self._encode(obj)
#     250 finally:
#     251     del self._circular[ident]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:274, in Serializer._encode(self, obj)
#     272     return self._encode_tuple(obj)
#     273 elif isinstance(obj, list):
# --> 274     return self._encode_list(obj)
#     275 elif isinstance(obj, set):
#     276     return self._encode_set(obj)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:317, in Serializer._encode_list(self, obj)
#     316 def _encode_list(self, obj: list[Any]) -> ArrayRepLike:
# --> 317     return [self.encode(item) for item in obj]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:317, in <listcomp>(.0)
#     316 def _encode_list(self, obj: list[Any]) -> ArrayRepLike:
# --> 317     return [self.encode(item) for item in obj]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:249, in Serializer.encode(self, obj)
#     247 self._circular[ident] = obj
#     248 try:
# --> 249     return self._encode(obj)
#     250 finally:
#     251     del self._circular[ident]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:258, in Serializer._encode(self, obj)
#     256 def _encode(self, obj: Any) -> AnyRep:
#     257     if isinstance(obj, Serializable):
# --> 258         return obj.to_serializable(self)
#     259     elif (encoder := self._encoders.get(type(obj))) is not None:
#     260         return encoder(obj, self)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/model/model.py:525, in Model.to_serializable(self, serializer)
#     522 def to_serializable(self, serializer: Serializer) -> ObjectRefRep:
#     523     serializer.add_ref(self, self.ref)
# --> 525     super_rep = super().to_serializable(serializer)
#     526     rep = ObjectRefRep(
#     527         type="object",
#     528         name=super_rep["name"],
#     529         id=self.id,
#     530     )
#     532     attributes = super_rep.get("attributes")
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/has_props.py:406, in HasProps.to_serializable(self, serializer)
#     400 rep = ObjectRep(
#     401     type="object",
#     402     name=self.__qualified_model__,
#     403 )
#     405 properties = self.properties_with_values(include_defaults=False)
# --> 406 attributes = {key: serializer.encode(val) for key, val in properties.items()}
#     408 if attributes:
#     409     rep["attributes"] = attributes
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/has_props.py:406, in <dictcomp>(.0)
#     400 rep = ObjectRep(
#     401     type="object",
#     402     name=self.__qualified_model__,
#     403 )
#     405 properties = self.properties_with_values(include_defaults=False)
# --> 406 attributes = {key: serializer.encode(val) for key, val in properties.items()}
#     408 if attributes:
#     409     rep["attributes"] = attributes
#
#     [... skipping similar frames: Serializer.encode at line 249 (1 times)]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:274, in Serializer._encode(self, obj)
#     272     return self._encode_tuple(obj)
#     273 elif isinstance(obj, list):
# --> 274     return self._encode_list(obj)
#     275 elif isinstance(obj, set):
#     276     return self._encode_set(obj)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:317, in Serializer._encode_list(self, obj)
#     316 def _encode_list(self, obj: list[Any]) -> ArrayRepLike:
# --> 317     return [self.encode(item) for item in obj]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:317, in <listcomp>(.0)
#     316 def _encode_list(self, obj: list[Any]) -> ArrayRepLike:
# --> 317     return [self.encode(item) for item in obj]
#
#     [... skipping similar frames: Serializer.encode at line 249 (1 times)]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:258, in Serializer._encode(self, obj)
#     256 def _encode(self, obj: Any) -> AnyRep:
#     257     if isinstance(obj, Serializable):
# --> 258         return obj.to_serializable(self)
#     259     elif (encoder := self._encoders.get(type(obj))) is not None:
#     260         return encoder(obj, self)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/model/model.py:525, in Model.to_serializable(self, serializer)
#     522 def to_serializable(self, serializer: Serializer) -> ObjectRefRep:
#     523     serializer.add_ref(self, self.ref)
# --> 525     super_rep = super().to_serializable(serializer)
#     526     rep = ObjectRefRep(
#     527         type="object",
#     528         name=super_rep["name"],
#     529         id=self.id,
#     530     )
#     532     attributes = super_rep.get("attributes")
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/has_props.py:406, in HasProps.to_serializable(self, serializer)
#     400 rep = ObjectRep(
#     401     type="object",
#     402     name=self.__qualified_model__,
#     403 )
#     405 properties = self.properties_with_values(include_defaults=False)
# --> 406 attributes = {key: serializer.encode(val) for key, val in properties.items()}
#     408 if attributes:
#     409     rep["attributes"] = attributes
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/has_props.py:406, in <dictcomp>(.0)
#     400 rep = ObjectRep(
#     401     type="object",
#     402     name=self.__qualified_model__,
#     403 )
#     405 properties = self.properties_with_values(include_defaults=False)
# --> 406 attributes = {key: serializer.encode(val) for key, val in properties.items()}
#     408 if attributes:
#     409     rep["attributes"] = attributes
#
#     [... skipping similar frames: Serializer.encode at line 249 (3 times), <dictcomp> at line 406 (1 times), <listcomp> at line 317 (1 times), Serializer._encode at line 274 (1 times), Serializer._encode at line 258 (1 times), Serializer._encode_list at line 317 (1 times), Model.to_serializable at line 525 (1 times), HasProps.to_serializable at line 406 (1 times)]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:278, in Serializer._encode(self, obj)
#     276     return self._encode_set(obj)
#     277 elif isinstance(obj, dict):
# --> 278     return self._encode_dict(obj)
#     279 elif isinstance(obj, bytes):
#     280     return self._encode_bytes(obj)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:334, in Serializer._encode_dict(self, obj)
#     330     return MapRep(type="map")
#     331 else:
#     332     return MapRep(
#     333         type="map",
# --> 334         entries=[(self.encode(key), self.encode(val)) for key, val in obj.items()],
#     335     )
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:334, in <listcomp>(.0)
#     330     return MapRep(type="map")
#     331 else:
#     332     return MapRep(
#     333         type="map",
# --> 334         entries=[(self.encode(key), self.encode(val)) for key, val in obj.items()],
#     335     )
#
#     [... skipping similar frames: Serializer.encode at line 249 (3 times), <dictcomp> at line 406 (1 times), <listcomp> at line 317 (1 times), Serializer._encode at line 274 (1 times), Serializer._encode at line 258 (1 times), Serializer._encode_list at line 317 (1 times), Model.to_serializable at line 525 (1 times), HasProps.to_serializable at line 406 (1 times)]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:278, in Serializer._encode(self, obj)
#     276     return self._encode_set(obj)
#     277 elif isinstance(obj, dict):
# --> 278     return self._encode_dict(obj)
#     279 elif isinstance(obj, bytes):
#     280     return self._encode_bytes(obj)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:334, in Serializer._encode_dict(self, obj)
#     330     return MapRep(type="map")
#     331 else:
#     332     return MapRep(
#     333         type="map",
# --> 334         entries=[(self.encode(key), self.encode(val)) for key, val in obj.items()],
#     335     )
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:334, in <listcomp>(.0)
#     330     return MapRep(type="map")
#     331 else:
#     332     return MapRep(
#     333         type="map",
# --> 334         entries=[(self.encode(key), self.encode(val)) for key, val in obj.items()],
#     335     )
#
#     [... skipping similar frames: Serializer.encode at line 249 (5 times), <dictcomp> at line 406 (2 times), <listcomp> at line 334 (2 times), Serializer._encode at line 278 (2 times), Serializer._encode at line 258 (2 times), Serializer._encode_dict at line 334 (2 times), Model.to_serializable at line 525 (2 times), HasProps.to_serializable at line 406 (2 times)]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:274, in Serializer._encode(self, obj)
#     272     return self._encode_tuple(obj)
#     273 elif isinstance(obj, list):
# --> 274     return self._encode_list(obj)
#     275 elif isinstance(obj, set):
#     276     return self._encode_set(obj)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:317, in Serializer._encode_list(self, obj)
#     316 def _encode_list(self, obj: list[Any]) -> ArrayRepLike:
# --> 317     return [self.encode(item) for item in obj]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:317, in <listcomp>(.0)
#     316 def _encode_list(self, obj: list[Any]) -> ArrayRepLike:
# --> 317     return [self.encode(item) for item in obj]
#
#     [... skipping similar frames: Serializer.encode at line 249 (1 times)]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:258, in Serializer._encode(self, obj)
#     256 def _encode(self, obj: Any) -> AnyRep:
#     257     if isinstance(obj, Serializable):
# --> 258         return obj.to_serializable(self)
#     259     elif (encoder := self._encoders.get(type(obj))) is not None:
#     260         return encoder(obj, self)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/model/model.py:525, in Model.to_serializable(self, serializer)
#     522 def to_serializable(self, serializer: Serializer) -> ObjectRefRep:
#     523     serializer.add_ref(self, self.ref)
# --> 525     super_rep = super().to_serializable(serializer)
#     526     rep = ObjectRefRep(
#     527         type="object",
#     528         name=super_rep["name"],
#     529         id=self.id,
#     530     )
#     532     attributes = super_rep.get("attributes")
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/has_props.py:406, in HasProps.to_serializable(self, serializer)
#     400 rep = ObjectRep(
#     401     type="object",
#     402     name=self.__qualified_model__,
#     403 )
#     405 properties = self.properties_with_values(include_defaults=False)
# --> 406 attributes = {key: serializer.encode(val) for key, val in properties.items()}
#     408 if attributes:
#     409     rep["attributes"] = attributes
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/has_props.py:406, in <dictcomp>(.0)
#     400 rep = ObjectRep(
#     401     type="object",
#     402     name=self.__qualified_model__,
#     403 )
#     405 properties = self.properties_with_values(include_defaults=False)
# --> 406 attributes = {key: serializer.encode(val) for key, val in properties.items()}
#     408 if attributes:
#     409     rep["attributes"] = attributes
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:249, in Serializer.encode(self, obj)
#     247 self._circular[ident] = obj
#     248 try:
# --> 249     return self._encode(obj)
#     250 finally:
#     251     del self._circular[ident]
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:278, in Serializer._encode(self, obj)
#     276     return self._encode_set(obj)
#     277 elif isinstance(obj, dict):
# --> 278     return self._encode_dict(obj)
#     279 elif isinstance(obj, bytes):
#     280     return self._encode_bytes(obj)
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:334, in Serializer._encode_dict(self, obj)
#     330     return MapRep(type="map")
#     331 else:
#     332     return MapRep(
#     333         type="map",
# --> 334         entries=[(self.encode(key), self.encode(val)) for key, val in obj.items()],
#     335     )
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:334, in <listcomp>(.0)
#     330     return MapRep(type="map")
#     331 else:
#     332     return MapRep(
#     333         type="map",
# --> 334         entries=[(self.encode(key), self.encode(val)) for key, val in obj.items()],
#     335     )
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:245, in Serializer.encode(self, obj)
#     243 ident = id(obj)
#     244 if ident in self._circular:
# --> 245     self.error("circular reference")
#     247 self._circular[ident] = obj
#     248 try:
#
# File ~/miniconda3/envs/CIDview/lib/python3.10/site-packages/bokeh/core/serialization.py:461, in Serializer.error(self, message)
#     460 def error(self, message: str) -> NoReturn:
# --> 461     raise SerializationError(message)
#
# SerializationError: circular reference

# %%
# test = bk.json_item(layout)

# %%
tab_layout = bk.TabPanel(child=layout, title='Main')

if q_original['hide_settings_panel']:
    
    my_layout = bk.Tabs(tabs=[tab_layout])
    
else:    

    tab_settings = bk.TabPanel(child=settings_layout, title='Settings')
    my_layout = bk.Tabs(tabs=[tab_layout, tab_settings])
    
    
# test = bk.json_item(my_layout) 

html = bk.file_html(my_layout, bk.CDN, q_original['html_title'], template=mdl.template)
with open(html_dir + q['webpage_name'], 'wt') as _:
    _.write(html)
    
print(f"generated {q_original['webpage_name']}")

# %%
try: fin_snd = int_mdl.fin_snd
except: fin_snd = None
    
fin_snd

# %%
print('success!')
# Out:
# success!
